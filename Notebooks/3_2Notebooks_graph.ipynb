# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://plotly.github.io/datasets/country_indicators.csv')

# %%
df.head()
# Out:
#   Country Name                                     Indicator Name  Year  \
# 0   Arab World                Agriculture, value added (% of GDP)  1962
# 1   Arab World             CO2 emissions (metric tons per capita)  1962
# 2   Arab World  Domestic credit provided by financial sector (...  1962
# 3   Arab World        Electric power consumption (kWh per capita)  1962
# 4   Arab World       Energy use (kg of oil equivalent per capita)  1962
#
#        Value
# 0        NaN
# 1   0.760996
# 2  18.168690
# 3        NaN
# 4        NaN

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")

# %%
df['Launch Site'].unique()
# Out:
# <ArrowStringArray>
# ['CCAFS LC-40', 'VAFB SLC-4E', 'KSC LC-39A', 'CCAFS SLC-40']
# Length: 4, dtype: str

# %%
df.head()
# Out:
#    Unnamed: 0  Flight Number  Launch Site  class  Payload Mass (kg)  \
# 0           0              1  CCAFS LC-40      0                0.0
# 1           1              2  CCAFS LC-40      0                0.0
# 2           2              3  CCAFS LC-40      0              525.0
# 3           3              4  CCAFS LC-40      0              500.0
# 4           4              5  CCAFS LC-40      0              677.0
#
#   Booster Version Booster Version Category  result
# 0  F9 v1.0  B0003                     v1.0   False
# 1  F9 v1.0  B0004                     v1.0   False
# 2  F9 v1.0  B0005                     v1.0   False
# 3  F9 v1.0  B0006                     v1.0   False
# 4  F9 v1.0  B0007                     v1.0   False

# %%
df['result'] = df['class'] == 1

# %%
df['class'].value_counts()
# Out:
# class
# 0    32
# 1    24
# Name: count, dtype: int64

# %%
(
            
df['class']
            .map({0: 'Failure', 1: 'Success'})
            .value_counts()
            .reset_index()
        )
# Out:
#      class  count
# 0  Failure     32
# 1  Success     24
